# %%
# %pip install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio in c:\users\사용자\appdata\roaming\python\python311\site-packages (5.15.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.115.8)
# Requirement already satisfied: ffmpy in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (1.7.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: orjson~=3.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (2.10.6)
# Requirement already satisfied: pydub in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.9.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio-client==1.7.0->gradio) (2025.2.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from gradio-client==1.7.0->gradio) (14.2)
# Requirement already satisfied: idna>=2.8 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\사용자\appdata\roaming\python\python311\site-packages (from httpx>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\사용자\appdata\roaming\python\python311\site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\사용자\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.28.1->gradio) (3.16.1)
# Requirement already satisfied: requests in c:\users\사용자\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from pydantic>=2.0->gradio) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\사용자\appdata\roaming\python\python311\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\사용자\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gradio as gr

# %%
def greet(name):
    return "Hello" + name + "!"

demo = gr.Interface(fn=greet, inputs='text', outputs ="text")
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7878
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7878/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def greet(name):
    return "Hello world, {}!!!".format(name)

with gr.Blocks() as demo:
    gr.Markdown("#Hello world")

    with gr.Row():
        input_textbox = gr.Textbox(label="입력")
        output_textbox = gr.Textbox(label="출력", interactive=False)

    send_button = gr.Button("전송")
    send_button.click(fn=greet, inputs=[input_textbox], outputs = [output_textbox])

    with gr.Row():
        input2_textbox= gr.Textbox(label="입력2")
        output2_textbox = gr.Textbox(label="실시간 출력")

    input2_textbox.change(fn=greet, inputs=[input2_textbox], outputs=[output2_textbox])    

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7879
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7879/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def click_send(sl, sw, pl, pw):
    return "{} {} {}".format(sl, sw, pl, pw)


with gr.Blocks() as demo:
    gr.Markdown("# 붓꽃 예측!!!")
    with gr.Row():

       sepal_length_textbox = gr.Textbox(label="꽃받침 길이")
       sepal_width_textbox = gr.Textbox(label="꽃받침 넓이")
       petal_length_textbox = gr.Textbox(label="꽃잎 길이")
       petal_width_textbox = gr.Textbox(label="꽃잎 넓이")

    send_button = gr.Button("전송")
    output_textbox = gr.Textbox(label="출력")

    send_button.click(fn=click_send, inputs=[sepal_length_textbox, sepal_width_textbox, petal_length_textbox, petal_width_textbox],
                      outputs = [output_textbox])
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7880
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7880/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import requests
import json
import matplotlib.pyplot as plt

# %%
def request_iris_prediction(data_list):

    # endpoint
    endpoint = "http://c8036432-a374-4b6f-b89d-067ef0d15b8a.koreacentral.azurecontainer.io/score"
    # method : post
    # headers
    headers = { 
        "Content-Type" : "application/json",
        "Authorization" : "Bearer VIrzntKeu94DrPK0KVx9ktjtYklFROHS"
    }
    # body
    body={
        "Inputs": {
            "input1": data_list
          
        }

    }

    response = requests.post(endpoint, headers=headers, json=body)
    print(response) 
    if response.status_code == 200:
        response_json = response.json()
        return response_json ["Results"]["WebServiceOutput0"]
    else:
        return "" 
def save_plot(data_points):
    # 센터로이드의 평균 위치를 계산하기 위한 변수 초기화
    centroid_positions = {0: [0, 0], 1: [0, 0], 2: [0, 0]}
    centroid_colors = {0: 'b', 1: 'r', 2: 'g'}  # 클러스터 색상
    
    # 데이터 포인트를 기반으로 센터로이드 위치 계산
    for point in data_points:
        assignment = point["Assignments"]
    
        # 각 클러스터별로 거리 데이터 가져오기
        for i in range(3):
            dist_key = f"DistancesToClusterCenter no.{i}"
            if dist_key in point:
                # 위치의 평균 계산
                centroid_positions[i][0] += (point["sepal_length_cm"] + point[dist_key]) / 2
                centroid_positions[i][1] += (point["sepal_width_cm"] + point[dist_key]) / 2
    
    # 평균값으로 센터로이드 위치 계산
    for i in range(3):
        centroid_positions[i][0] /= len(data_points)
        centroid_positions[i][1] /= len(data_points)
    
    plt.figure(figsize=(8, 6))
    
    point_index = 0
    # 데이터 포인트 그리기
    for point in data_points:
        point_index += 1
        plt.scatter(point["sepal_length_cm"], point["sepal_width_cm"],
                    c='b' if point["Assignments"] == 0 else 'r' if point["Assignments"] == 1 else 'g')
        plt.text(point["sepal_length_cm"], point["sepal_width_cm"], f"{point_index}")

    # 클러스터 센터로이드 그리기
    for cluster, (x, y) in centroid_positions.items():
        plt.scatter(x, y, c=centroid_colors[cluster], marker='X', s=200)

    plt.title('Data Points and Cluster Centroids')
    plt.xlabel('Sepal Length (cm)')
    plt.ylabel('Sepal Width (cm)')
    plt.grid()
    plt.savefig('iris_clusters.png')
    plt.close()  # plt.show() 대신 plt.close()를 사용
    return 'iris_clusters.png'  # 현재 figure 반환


with gr.Blocks() as demo:
    gr.Markdown("# 붓꽃 예측!!!")

    view_count = gr.State(1)
    data_dict = dict()

    def click_send():
        data_list = list(data_dict.values())
        print(data_list)
        response_data = request_iris_prediction(data_list)
        image_path = save_plot(response_data)
        return json.dumps(response_data, indent=3), image_path
    # return "{}{}{}".format(sl, sw, pl, pw)
        
    def click_add(count):
        count+=1
        print("+ : {}".format(count))
        return count

    def click_delete(count):
        if count >1:
            count -= 1
        print("- : {}".format(count))
        return count    

    def change_data(row_index, sl, sw, pl, pw):
        print("{}{}{}{}".format(row_index, sl, sw, pl, pw))
        data_dict.update({
            row_index:{
                    "sepal_length_cm":sl,
                    "sepal_width_cm":sw,
                    "petal_length_cm":pl,
                    "petal_width_cm":pw,
                    "class":""
            }
        })
        print(data_dict)
        pass

    with gr.Row():
        add_button = gr.Button("+")
        delete_button = gr.Button("-")

    with gr.Column():

        @gr.render(inputs=[view_count])
        def render_input_components(count):

            for i in range(0, count):
                row_index = gr.State(i)
                with gr.Row():    

                    sepal_length_textbox = gr.Textbox(label="꽃받침 길이", key=f"sl-{i}")
                    sepal_width_textbox = gr.Textbox(label="꽃받침 넓이", key=f"sw-{i}")
                    petal_length_textbox = gr.Textbox(label="꽃잎 길이", key=f"pl-{i}")
                    petal_width_textbox = gr.Textbox(label="꽃잎 넓이", key=f"pw-{i}")

                    sepal_length_textbox.change(fn=change_data, inputs=[row_index, sepal_length_textbox, sepal_width_textbox, petal_length_textbox, petal_width_textbox], outputs=[])
                    sepal_width_textbox.change(fn=change_data, inputs=[row_index, sepal_length_textbox, sepal_width_textbox, petal_length_textbox, petal_width_textbox], outputs=[])
                    petal_length_textbox.change(fn=change_data, inputs=[row_index, sepal_length_textbox, sepal_width_textbox, petal_length_textbox, petal_width_textbox], outputs=[])
                    petal_width_textbox.change(fn=change_data, inputs=[row_index, sepal_length_textbox, sepal_width_textbox, petal_length_textbox, petal_width_textbox], outputs=[])

    send_button = gr.Button("전송")
    output_textbox = gr.Textbox(label="출력")
    output_image = gr.Image(label="Plot",interactive=False)

    add_button.click (fn=click_add, inputs=[view_count], outputs=[view_count])
    delete_button.click(fn=click_delete, inputs=[view_count], outputs=[view_count])

    send_button.click(fn=click_send, inputs=[], outputs = [output_textbox, output_image])
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7886
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7886/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 02
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '', 'petal_length_cm': '', 'petal_width_cm': '', 'class': ''}}
# 022
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '', 'petal_width_cm': '', 'class': ''}}
# 0222
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '', 'class': ''}}
# 0222
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}}
# [{'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}]
# <Response [200]>
# + : 2
# 13
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '', 'petal_length_cm': '', 'petal_width_cm': '', 'class': ''}}
# 133
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '', 'petal_width_cm': '', 'class': ''}}
# 1333
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '', 'class': ''}}
# 1333
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}}
# [{'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}]
# <Response [200]>
# + : 3
# 22
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '', 'petal_length_cm': '', 'petal_width_cm': '', 'class': ''}}
# 225
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '', 'petal_width_cm': '', 'class': ''}}
# 2252
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '2', 'petal_width_cm': '', 'class': ''}}
# 22520
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '20', 'petal_width_cm': '', 'class': ''}}
# 225204
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '204', 'petal_width_cm': '', 'class': ''}}
# 225204
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '204', 'petal_width_cm': '7', 'class': ''}}
# 22520
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '20', 'petal_width_cm': '7', 'class': ''}}
# 2252
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '2', 'petal_width_cm': '7', 'class': ''}}
# 2252.
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '2.', 'petal_width_cm': '7', 'class': ''}}
# 2252.3
# {0: {'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, 1: {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, 2: {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '2.3', 'petal_width_cm': '7', 'class': ''}}
# [{'sepal_length_cm': '2', 'sepal_width_cm': '2', 'petal_length_cm': '2', 'petal_width_cm': '2', 'class': ''}, {'sepal_length_cm': '3', 'sepal_width_cm': '3', 'petal_length_cm': '3', 'petal_width_cm': '3', 'class': ''}, {'sepal_length_cm': '2', 'sepal_width_cm': '5', 'petal_length_cm': '2.3', 'petal_width_cm': '7', 'class': ''}]
# <Response [200]>
